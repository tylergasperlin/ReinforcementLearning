# %%
import gymnasium as gym
import time

# %%
def simple_agent(observation):
    #observation
    position,velocity = observation
    
    if -0.1 < position < 0.4:
        action = 2
        
    elif velocity < 0 and position < -.2:
        action = 0
        
    else:
        action = 1
        
    return action

# %%
env = gym.make("MountainCar-v0", render_mode="human")
observation, info = env.reset(seed=42)
for step in range(600):
    # 0 left
    # 1 stay put
    # 2 right
    env.render()
    action = simple_agent(observation)
    
    observation, reward, terminated, truncated, info = env.step(action)
    
    print(f"obs: {observation}") # returns position and velocity
    time.sleep(0.001)
    
env.close()
# Out:
# obs: [-0.4457913  -0.00058252]
# obs: [-0.4479521  -0.00216079]
# obs: [-0.4516754  -0.00372328]
# obs: [-0.45693392 -0.00525853]
# obs: [-0.46368912 -0.00675519]
# obs: [-0.47189122 -0.0082021 ]
# obs: [-0.4814796  -0.00958835]
# obs: [-0.49238297 -0.01090341]
# obs: [-0.5045202  -0.01213718]
# obs: [-0.5178004 -0.0132802]
# obs: [-0.53212404 -0.01432368]
# obs: [-0.5473838  -0.01525975]
# obs: [-0.5634653  -0.01608151]
# obs: [-0.58024853 -0.01678323]
# obs: [-0.5976089 -0.0173604]
# obs: [-0.6154188  -0.01780987]
# obs: [-0.6335487  -0.01812989]
# obs: [-0.6518688  -0.01832014]
# obs: [-0.67025054 -0.01838169]
# obs: [-0.68856746 -0.01831694]
# obs: [-0.70669705 -0.01812956]
# obs: [-0.7245214  -0.01782435]
# obs: [-0.7419284  -0.01740704]
# obs: [-0.75881255 -0.01688416]
# obs: [-0.77507544 -0.01626286]
# obs: [-0.7906261  -0.01555067]
# obs: [-0.8053815 -0.0147554]
# obs: [-0.8192664  -0.01388489]
# obs: [-0.83221334 -0.01294694]
# obs: [-0.84416246 -0.01194912]
# obs: [-0.8550612  -0.01089872]
# obs: [-0.8648638  -0.00980266]
# obs: [-0.8735313  -0.00866744]
# obs: [-0.8810304  -0.00749913]
# obs: [-0.88733375 -0.00630338]
# obs: [-0.8924192  -0.00508542]
# obs: [-0.8962693  -0.00385012]
# obs: [-0.89887136 -0.00260204]
# obs: [-0.9002169  -0.00134549]
# obs: [-9.0030146e-01 -8.4615778e-05]
# obs: [-0.8991249   0.00117653]
# obs: [-0.89569104  0.0034339 ]
# obs: [-0.89001095  0.00568008]
# obs: [-0.88210374  0.00790723]
# obs: [-0.87199694  0.01010682]
# obs: [-0.85972756  0.01226937]
# obs: [-0.84534323  0.0143843 ]
# obs: [-0.8289035   0.01643976]
# obs: [-0.8104809   0.01842256]
# obs: [-0.7901627   0.02031822]
# obs: [-0.7680516   0.02211107]
# obs: [-0.74426717  0.02378449]
# obs: [-0.7189459   0.02532124]
# obs: [-0.69224197  0.02670391]
# obs: [-0.66432655  0.02791546]
# obs: [-0.6353867   0.02893985]
# obs: [-0.6056241   0.02976263]
# obs: [-0.5752524   0.03037162]
# obs: [-0.5444949   0.03075748]
# obs: [-0.51358086  0.0309141 ]
# obs: [-0.4827419   0.03083898]
# obs: [-0.45220855  0.03053332]
# obs: [-0.42220658  0.03000197]
# obs: [-0.3929534  0.0292532]
# obs: [-0.36465514  0.02829826]
# obs: [-0.3375043   0.02715084]
# obs: [-0.31167778  0.02582651]
# obs: [-0.28733572  0.02434204]
# obs: [-0.264621    0.02271475]
# obs: [-0.24365897  0.02096201]
# obs: [-0.22455828  0.0191007 ]
# obs: [-0.20741141  0.01714686]
# obs: [-0.192296    0.01511542]
# obs: [-0.17927599  0.01302001]
# obs: [-0.16840303  0.01087295]
# obs: [-0.15971777  0.00868527]
# obs: [-0.15325096  0.0064668 ]
# obs: [-0.14902456  0.0042264 ]
# obs: [-0.14705245  0.00197211]
# obs: [-0.14734098 -0.00028854]
# obs: [-0.14988925 -0.00254826]
# obs: [-0.15468898 -0.00479974]
# obs: [-0.16172431 -0.00703534]
# obs: [-0.17097114 -0.00924682]
# obs: [-0.18239625 -0.01142512]
# obs: [-0.19595635 -0.01356009]
# obs: [-0.21159676 -0.0156404 ]
# obs: [-0.23025015 -0.01865339]
# obs: [-0.25183046 -0.02158031]
# obs: [-0.2762306  -0.02440015]
# obs: [-0.30332038 -0.02708975]
# obs: [-0.33294457 -0.02962419]
# obs: [-0.36492196 -0.0319774 ]
# obs: [-0.399045   -0.03412304]
# obs: [-0.43508062 -0.0360356 ]
# obs: [-0.47277233 -0.03769172]
# obs: [-0.51184374 -0.03907144]
# obs: [-0.5520033  -0.04015958]
# obs: [-0.59295017 -0.04094681]
# obs: [-0.6343806  -0.04143042]
# obs: [-0.67599535 -0.04161476]
# obs: [-0.7175065  -0.04151119]
# obs: [-0.75864404 -0.04113753]
# obs: [-0.79916126 -0.04051719]
# obs: [-0.83883923 -0.03967796]
# obs: [-0.87748986 -0.03865066]
# obs: [-0.9149576  -0.03746773]
# obs: [-0.9511195 -0.0361619]
# obs: [-0.98588455 -0.03476503]
# obs: [-1.0191917 -0.0333072]
# obs: [-1.0510077  -0.03181602]
# obs: [-1.081324   -0.03031618]
# obs: [-1.1101532  -0.02882927]
# obs: [-1.137527   -0.02737373]
# obs: [-1.1634918  -0.02596496]
# obs: [-1.1881075  -0.02461557]
# obs: [-1.2  0. ]
# obs: [-1.1977581  0.0022419]
# obs: [-1.1932669   0.00449118]
# obs: [-1.186512    0.00675497]
# obs: [-1.1774722   0.00903978]
# obs: [-1.1661209   0.01135127]
# obs: [-1.1524271   0.01369384]
# obs: [-1.1363567  0.0160703]
# obs: [-1.1178753  0.0184814]
# obs: [-1.0969499   0.02092541]
# obs: [-1.0735524   0.02339762]
# obs: [-1.0476625   0.02588981]
# obs: [-1.0192727   0.02838981]
# obs: [-0.9883917   0.03088104]
# obs: [-0.95504946  0.03334223]
# obs: [-0.9193021   0.03574732]
# obs: [-0.88123655  0.03806554]
# obs: [-0.84097457  0.04026203]
# obs: [-0.7986759   0.04229866]
# obs: [-0.75454044  0.04413542]
# obs: [-0.70880824  0.0457322 ]
# obs: [-0.66175735  0.0470509 ]
# obs: [-0.6136997   0.04805768]
# obs: [-0.5649745   0.04872523]
# obs: [-0.5159397   0.04903475]
# obs: [-0.4669624   0.04897732]
# obs: [-0.4184078   0.04855458]
# obs: [-0.37062913  0.04777868]
# obs: [-0.32395786  0.04667126]
# obs: [-0.278696    0.04526187]
# obs: [-0.23511006  0.04358594]
# obs: [-0.1934276   0.04168245]
# obs: [-0.15383592  0.03959168]
# obs: [-0.11648269  0.03735323]
# obs: [-0.08147837  0.03500432]
# obs: [-0.04789973  0.03357864]
# obs: [-0.01579533  0.03210441]
# obs: [0.01481188 0.03060721]
# obs: [0.04392156 0.02910968]
# obs: [0.07155291 0.02763135]
# obs: [0.09774164 0.02618873]
# obs: [0.12253708 0.02479544]
# obs: [0.14599954 0.02346246]
# obs: [0.16819799 0.02219846]
# obs: [0.18920803 0.02101003]
# obs: [0.20911011 0.01990208]
# obs: [0.2279882  0.01887809]
# obs: [0.2459286 0.0179404]
# obs: [0.26301908 0.0170905 ]
# obs: [0.2793483  0.01632922]
# obs: [0.29500523 0.01565692]
# obs: [0.31007895 0.01507373]
# obs: [0.32465857 0.01457962]
# obs: [0.33883315 0.01417458]
# obs: [0.35269186 0.01385872]
# obs: [0.36632422 0.01363234]
# obs: [0.3798203  0.01349606]
# obs: [0.39327112 0.01345085]
# obs: [0.40676925 0.01349811]
# obs: [0.41940895 0.01263972]
# obs: [0.4312799  0.01187095]
# obs: [0.44246727 0.01118738]
# obs: [0.45305216 0.01058488]
# obs: [0.4631119  0.01005973]
# obs: [0.47272044 0.00960856]
# obs: [0.4819489  0.00922845]
# obs: [0.4908658  0.00891689]
# obs: [0.4995376  0.00867179]
# obs: [0.50802904 0.00849149]
# obs: [0.5164038  0.00837475]
# obs: [0.5247246 0.0083208]
# obs: [0.5330539  0.00832924]
# obs: [0.541454   0.00840014]
# obs: [0.549988   0.00853399]
# obs: [0.5587197  0.00873171]
# obs: [0.56771433 0.00899463]
# obs: [0.5770389  0.00932453]
# obs: [0.5867625  0.00972361]
# obs: [0.59695697 0.01019451]
# obs: [0.6        0.01074027]
# obs: [0.6        0.01130827]
# obs: [0.6        0.01187628]
# obs: [0.6        0.01244428]
# obs: [0.6        0.01301229]
# obs: [0.6        0.01358029]
# obs: [0.6       0.0141483]
# obs: [0.6       0.0147163]
# obs: [0.6        0.01528431]
# obs: [0.6        0.01585232]
# obs: [0.6        0.01642032]
# obs: [0.6        0.01698833]
# obs: [0.6        0.01755633]
# obs: [0.6        0.01812434]
# obs: [0.6        0.01869234]
# obs: [0.6        0.01926035]
# obs: [0.6        0.01982835]
# obs: [0.6        0.02039636]
# obs: [0.6        0.02096436]
# obs: [0.6        0.02153237]
# obs: [0.6        0.02210037]
# obs: [0.6        0.02266838]
# obs: [0.6        0.02323638]
# obs: [0.6        0.02380439]
# obs: [0.6        0.02437239]
# obs: [0.6       0.0249404]
# obs: [0.6       0.0255084]
# obs: [0.6        0.02607641]
# obs: [0.6        0.02664441]
# obs: [0.6        0.02721242]
# obs: [0.6        0.02778042]
# obs: [0.6        0.02834843]
# obs: [0.6        0.02891644]
# obs: [0.6        0.02948444]
# obs: [0.6        0.03005245]
# obs: [0.6        0.03062045]
# obs: [0.6        0.03118846]
# obs: [0.6        0.03175646]
# obs: [0.6        0.03232447]
# obs: [0.6        0.03289247]
# obs: [0.6        0.03346048]
# obs: [0.6        0.03402848]
# obs: [0.6        0.03459649]
# obs: [0.6        0.03516449]
# obs: [0.6       0.0357325]
# obs: [0.6       0.0363005]
# obs: [0.6        0.03686851]
# obs: [0.6        0.03743652]
# obs: [0.6        0.03800452]
# obs: [0.6        0.03857252]
# obs: [0.6        0.03914053]
# obs: [0.6        0.03970854]
# obs: [0.6        0.04027654]
# obs: [0.6        0.04084454]
# obs: [0.6        0.04141255]
# obs: [0.6        0.04198056]
# obs: [0.6        0.04254856]
# obs: [0.6        0.04311657]
# obs: [0.6        0.04368457]
# obs: [0.6        0.04425258]
# obs: [0.6        0.04482058]
# obs: [0.6        0.04538859]
# obs: [0.6        0.04595659]
# obs: [0.6       0.0465246]
# obs: [0.6       0.0470926]
# obs: [0.6        0.04766061]
# obs: [0.6        0.04822861]
# obs: [0.6        0.04879662]
# obs: [0.6        0.04936462]
# obs: [0.6        0.04993263]
# obs: [0.6        0.05050064]
# obs: [0.6        0.05106864]
# obs: [0.6        0.05163664]
# obs: [0.6        0.05220465]
# obs: [0.6        0.05277266]
# obs: [0.6        0.05334066]
# obs: [0.6        0.05390866]
# obs: [0.6        0.05447667]
# obs: [0.6        0.05504468]
# obs: [0.6        0.05561268]
# obs: [0.6        0.05618069]
# obs: [0.6        0.05674869]
# obs: [0.6       0.0573167]
# obs: [0.6       0.0578847]
# obs: [0.6        0.05845271]
# obs: [0.6        0.05902071]
# obs: [0.6        0.05958872]
# obs: [0.6        0.06015673]
# obs: [0.6        0.06072473]
# obs: [0.6        0.06129273]
# obs: [0.6        0.06186074]
# obs: [0.6        0.06242875]
# obs: [0.6        0.06299675]
# obs: [0.6        0.06356476]
# obs: [0.6        0.06413276]
# obs: [0.6        0.06470077]
# obs: [0.6        0.06526877]
# obs: [0.6        0.06583678]
# obs: [0.6        0.06640478]
# obs: [0.6        0.06697278]
# obs: [0.6        0.06754079]
# obs: [0.6       0.0681088]
# obs: [0.6       0.0686768]
# obs: [0.6        0.06924481]
# obs: [0.6        0.06981281]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
# obs: [0.6  0.07]
